# %% [markdown]
# # <img style="float: left; padding-right: 20px; height: 70px" src="https://scontent.flpb2-1.fna.fbcdn.net/v/t39.30808-6/333037578_535368228681036_1718744419186811485_n.jpg?_nc_cat=101&ccb=1-7&_nc_sid=09cbfe&_nc_ohc=Y0wrgOHt3UIAX_CTUKQ&_nc_ht=scontent.flpb2-1.fna&oh=00_AfBfGzpo0-x8gU11VFnWwNRJ-1tOK9hv1D7JAHfZhFfzOw&oe=648C289F"> Herramientas Básicas de Visualización de Datos
#
# # 🍷 Análisis Exploratorio de Datos de Calidad de Vinos 📊🍇
#
# **Universidad Privada Boliviana**<br/>
# **Diplomado en Machine Learning y Ciencia de Datos 2-2023**<br/>
# **Junio 2023**<br/>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Importación de Datos 📥

# %%
df = pd.read_csv('wines.csv')

# %%
# Ver las columnas
df.head()
# Out:
#    Unnamed: 0  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0           0            8.9             0.590         0.50             2.0
# 1           1            7.7             0.690         0.22             1.9
# 2           2            8.8             0.685         0.26             1.6
# 3           3           11.4             0.460         0.50             2.7
# 4           4            8.8             0.240         0.54             2.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.337                 27.0                  81.0  0.99640  3.04
# 1      0.084                 18.0                  94.0  0.99610  3.31
# 2      0.088                 16.0                  23.0  0.99694  3.32
# 3      0.122                  4.0                  17.0  1.00060  3.13
# 4      0.083                 25.0                  57.0  0.99830  3.39
#
#    sulphates  alcohol  quality  red
# 0       1.61      9.5        6    1
# ...

# %%
# eliminar las que no sean necesarias
df.drop("Unnamed: 0", axis=1, inplace=True)

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            8.9             0.590         0.50             2.0      0.337
# 1            7.7             0.690         0.22             1.9      0.084
# 2            8.8             0.685         0.26             1.6      0.088
# 3           11.4             0.460         0.50             2.7      0.122
# 4            8.8             0.240         0.54             2.5      0.083
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 27.0                  81.0  0.99640  3.04       1.61
# 1                 18.0                  94.0  0.99610  3.31       0.48
# 2                 16.0                  23.0  0.99694  3.32       0.47
# 3                  4.0                  17.0  1.00060  3.13       0.70
# 4                 25.0                  57.0  0.99830  3.39       0.54
#
#    alcohol  quality  red
# 0      9.5        6    1
# 1      9.5        5    1
# ...

# %%
# Alternativa para leer estos datos
...

# %%
## Leer los datos en la variable df
df = pd.read_csv("wines.csv",index_col="Unnamed: 0")

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            8.9             0.590         0.50             2.0      0.337
# 1            7.7             0.690         0.22             1.9      0.084
# 2            8.8             0.685         0.26             1.6      0.088
# 3           11.4             0.460         0.50             2.7      0.122
# 4            8.8             0.240         0.54             2.5      0.083
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 27.0                  81.0  0.99640  3.04       1.61
# 1                 18.0                  94.0  0.99610  3.31       0.48
# 2                 16.0                  23.0  0.99694  3.32       0.47
# 3                  4.0                  17.0  1.00060  3.13       0.70
# 4                 25.0                  57.0  0.99830  3.39       0.54
#
#    alcohol  quality  red
# 0      9.5        6    1
# 1      9.5        5    1
# ...

# %% [markdown]
# ### 🧮 ¿Cuántas registros de datos contiene dataframe?

# %%
df.shape
# Out:
# (1000, 13)

# %% [markdown]
# ### 🔍 Exploración detallada de información y tipos de datos en cada columna del dataframe.\
#
# ¿Cuál es la información general de cada columna, como el tipo de datos y la cantidad de valores no nulos?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1000 non-null   float64
#  1   volatile acidity      1000 non-null   float64
#  2   citric acid           1000 non-null   float64
#  3   residual sugar        1000 non-null   float64
#  4   chlorides             1000 non-null   float64
#  5   free sulfur dioxide   1000 non-null   float64
#  6   total sulfur dioxide  1000 non-null   float64
#  7   density               1000 non-null   float64
#  8   pH                    1000 non-null   float64
#  9   sulphates             1000 non-null   float64
#  10  alcohol               1000 non-null   float64
#  11  quality               1000 non-null   int64
#  12  red                   1000 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 109.4 KB

# %% [markdown]
# ### Estadísticas descriptivas de las variables 📈🔎
# ¿Cuáles son las estadísticas descriptivas de las variables numéricas?

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1000.000000       1000.000000   1000.00000     1000.000000
# mean        7.558400          0.397455      0.30676        4.489250
# std         1.559455          0.189923      0.16783        4.112419
# min         3.800000          0.080000      0.00000        0.800000
# 25%         6.500000          0.260000      0.22000        1.800000
# 50%         7.200000          0.340000      0.30000        2.400000
# 75%         8.200000          0.520000      0.40000        6.100000
# max        15.500000          1.580000      1.00000       26.050000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1000.000000           1000.00000            1000.00000  1000.000000
# mean      0.067218             25.29650              91.03100     0.995351
# std       0.046931             17.06237              59.57269     0.002850
# ...

# %% [markdown]
# ###  Diversidad de datos 🔍

# %% [markdown]
# ¿Cuál es la cantidad total de valores únicos en cada columna?

# %%
df.nunique()
# Out:
# fixed acidity            84
# volatile acidity        127
# citric acid              78
# residual sugar          173
# chlorides               145
# free sulfur dioxide      85
# total sulfur dioxide    219
# density                 434
# pH                       87
# sulphates                86
# alcohol                  66
# quality                   6
# red                       2
# dtype: int64

# %% [markdown]
# ¿Cuál es la media de la columna "residual sugar"?

# %%
df["residual sugar"].mean()
# Out:
# 4.48925

# %%
df["residual sugar"].median()
# Out:
# 2.4

# %% [markdown]
# ¿Cuál es el valor máximo de la columna "free sulfur dioxide"?

# %%
df["free sulfur dioxide"].max()
# Out:
# 131.0

# %% [markdown]
# ¿Cuántos vinos rojos y blancos hay en el dataframe?

# %%
df["red"].value_counts()
# Out:
# red
# 1    500
# 0    500
# Name: count, dtype: int64

# %% [markdown]
# ¿Cómo se distribuye la variable "quality" en términos de frecuencia?

# %%
plt.hist(df["quality"], bins=6)
plt.xlabel("Quality")
plt.ylabel("Frequency")
plt.title("Wines Quality Distribution")
plt.show()

# %% [markdown]
# ¿Cuál es la relación entre la variable "alcohol" y la variable objetivo "quality"?

# %%
plt.scatter(df.alcohol,df.quality)
plt.xlabel("Alcohol")
plt.ylabel("Quality")
plt.title("Alcohol and Quality relation")
plt.show()

# %%
# Utilizar box plot de matplotlib
grouped = df.groupby("quality")
grouped_data = grouped["alcohol"].apply(list)

plt.figure(figsize=(8,6))
plt.boxplot(grouped_data.values , labels=grouped_data.index)
plt.xlabel("quality")
plt.ylabel("Nivel de alcohol")
plt.title("Box plot de la distribucin de alcohol vs calidad")
plt.show()

# %%
# que tal con sns?
sns.boxplot(x="quality", y="alcohol", data=df)
plt.xlabel("Quality")
plt.ylabel("Alcohol Level", fontweight="bold")
plt.title("Box plot", fontweight="bold")
plt.savefig("datos.jpg")
plt.show()

# %% [markdown]
# ### ¿Hay alguna correlación entre las variables "fixed acidity" y "pH"?

# %%
# ###
plt.figure(figsize=(8,6))
plt.scatter(df["fixed acidity"],df["pH"], alpha=0.25, s=90, color="tab:green")
plt.xlabel("fixed acidity")
plt.ylabel("pH", fontweight="bold")
plt.title("relation", fontweight="bold")
plt.show()

# %% [markdown]
# ### ¿Cuál es el promedio de "fixed acidity" para cada calidad de vino?

# %%
###
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            8.9             0.590         0.50             2.0      0.337
# 1            7.7             0.690         0.22             1.9      0.084
# 2            8.8             0.685         0.26             1.6      0.088
# 3           11.4             0.460         0.50             2.7      0.122
# 4            8.8             0.240         0.54             2.5      0.083
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 27.0                  81.0  0.99640  3.04       1.61
# 1                 18.0                  94.0  0.99610  3.31       0.48
# 2                 16.0                  23.0  0.99694  3.32       0.47
# 3                  4.0                  17.0  1.00060  3.13       0.70
# 4                 25.0                  57.0  0.99830  3.39       0.54
#
#    alcohol  quality  red
# 0      9.5        6    1
# 1      9.5        5    1
# ...

# %%
df.groupby("quality")["fixed acidity"].mean()
# Out:
# quality
# 3    9.933333
# 4    7.506452
# 5    7.617101
# 6    7.599074
# 7    7.398193
# 8    6.830435
# Name: fixed acidity, dtype: float64

# %%
### mediante boxplot
grouped = df.groupby("quality")
grouped_data = grouped["fixed acidity"].apply(list)
#graphic
plt.figure(figsize=(8,6))
plt.boxplot(grouped_data.values , labels=grouped_data.index)
plt.xlabel("quality")
plt.ylabel("Fixed acidity")
plt.title("Box plot de la distribucin de fixed acidity vs calidad")
plt.show()

# %%
### box plot y violin plot
# que tal con sns?}
plt.figure(figsize=(8,6))
sns.set_style("whitegrid")
sns.boxplot(x="quality", y="fixed acidity", data=df)
plt.xlabel("Quality")
plt.ylabel("Fixed Acidity", fontweight="bold")
plt.title("Box plot", fontweight="bold")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.set_style("whitegrid")
sns.violinplot(x="quality", y="fixed acidity", data=df)
plt.xlabel("Quality")
plt.ylabel("Fixed Acidity", fontweight="bold")
plt.title("Violin plot", fontweight="bold")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.set_style("whitegrid")
sns.stripplot(x="quality", y="fixed acidity", data=df, jitter=0.25, s=10, alpha=0.2, edgecolor="black", linewidth=0.5)
plt.xlabel("Quality")
plt.ylabel("Fixed Acidity", fontweight="bold")
plt.title("Strip plot", fontweight="bold")
plt.show()

# %% [markdown]
# ### ¿Cuál es la media de "alcohol" para cada calidad de vino rojo?

# %%
###
df.head()
filter_red_wine= df["red"]==1
red_wines = df[filter_red_wine]
red_wines.head()
red_wines.groupby("quality")["alcohol"].median()
# Out:
# quality
# 3     9.90
# 4     9.90
# 5     9.55
# 6    10.50
# 7    11.50
# 8    11.80
# Name: alcohol, dtype: float64

# %%
# Crear un gráfico de caja utilizando sns.boxplot
plt.figure(figsize=(8,6))
sns.set_style("whitegrid")
sns.boxplot(x="quality", y="alcohol", data=red_wines)
plt.xlabel("Quality")
plt.ylabel("Alcohol", fontweight="bold")
plt.title("Box plot calidad para vinos rojos", fontweight="bold")
plt.show()

# %% [markdown]
# ### ¿Cómo se distribuye la variable "citric acid" para los vinos con una calidad mayor o igual a 7?

# %%
## en un hist plot
df.head()
filter_quality = df["quality"]>=7
high_quality_wines = df[filter_quality]
plt.hist(high_quality_wines["citric acid"])
plt.xlabel("Citric acid")
plt.ylabel("Frequency")
plt.title("Citric Acid Distribution")
plt.show()

# %% [markdown]
# ## ¿Cuál es la relación entre "volatile acidity" y "quality" para los vinos con un pH mayor a 3?

# %%
## scatter plot ?
filtro_ph = df["pH"]>3
ph_wines = df[filtro_ph]
plt.scatter(ph_wines["quality"], ph_wines["volatile acidity"])
plt.xlabel("Quality")
plt.ylabel("Volatile")
plt.title("Quality vs Volatile")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.set_style("whitegrid")
sns.boxplot(x="quality", y="volatile acidity", data= ph_wines)
plt.xlabel("Quality")
plt.ylabel("Volatile")
plt.title("Quality vs Volatile")
plt.show()

# %%
# Crear un gráfico de caja utilizando sns.boxplot

# %%
### como este bloque de codigo es utilizado frecuentemente, crear una funcion
def sns_box_plot_f(columna_x, columna_y, data_f):
    plt.figure(figsize=(8,6))
    sns.set_style("whitegrid")
    sns.boxplot(x=columna_x, y=columna_y, data= data_f)
    plt.xlabel(columna_x)
    plt.ylabel(columna_y)
    plt.title("Box plot de la dist. " + columna_x + " vs "+columna_y )
    plt.show()

# %%
###
sns_box_plot_f("quality", "fixed acidity", ph_wines)

# %% [markdown]
# ### ¿Cuál es el recuento de vinos con una concentración de "sulphates" superior a 0.5 para cada calidad?

# %%
###
filter_sulphates = df["sulphates"]>0.5
df_high_sulf = df[filter_sulphates]
df_high_sulf.head()
df_high_sulf.groupby("quality").size()
# Out:
# quality
# 3      2
# 4     17
# 5    213
# 6    285
# 7     97
# 8     14
# dtype: int64

# %%
### Utilizar la funcion creada
sns_box_plot_f("quality","sulphates", df_high_sulf)

# %% [markdown]
# ### ¿Cuál es la distribución de las calidades de los vinos utilizando un gráfico de barras?

# %%
## crear un plt.bar
df.head()
quality_counts = df["quality"].value_counts().sort_index(ascending=True)
plt.bar(quality_counts.index, quality_counts.values)
plt.xlabel("quality")
plt.ylabel("frequency")
plt.title("test")
# Out:
# Text(0.5, 1.0, 'test')

# %% [markdown]
# ### ¿Cuál es la relación entre "residual sugar" y "density" para los vinos con una calidad de 5 o 6?

# %%
### scatter plot
filtro_wine_quality = (df["quality"] == 5) | (df["quality"] ==6)
wines_t5_6 = df[filtro_wine_quality]
plt.scatter(wines_t5_6["residual sugar"], wines_t5_6["density"], s=100, alpha = 0.3)
plt.xlabel("residual sugar")
plt.ylabel("density")
plt.title("graphic")
# Out:
# Text(0.5, 1.0, 'graphic')

# %%
#  Mostrar todos los datos de fixed_acidity
df.head()
plt.plot(df["fixed acidity"])
plt.xlabel("Register number")
plt.ylabel("Fixed Acidity")
plt.title("All registers")
# Out:
# Text(0.5, 1.0, 'All registers')
