# %% [markdown]
# ## Importar datos y echar un vistazo

# %%
data1 = [71, 87, 21, 18, 32, 72, 75, 43, 56, 25, 90, 68, 32, 17, 19, 30, 38, 83, 94, 57, 25, 25, 51, 53, 90, 35, 71, 53, 93, 24, 34, 16, 38, 96, 23, 46, 76, 52, 92, 78, 22, 46, 68, 99, 28, 45, 53, 66, 84, 13, 22, 37, 24, 83, 92, 81, 34, 91, 18, 76, 17, 87, 94, 96, 56, 69, 27, 94, 30, 88, 85, 34, 67, 72, 64, 95, 77, 43, 66, 31, 20, 79, 77, 34, 87, 43, 86, 36, 75, 28, 98, 12, 10, 20, 30, 52, 81, 89, 61, 55, 73, 46, 33, 98, 70, 20, 51, 93, 33, 52, 94, 46, 83, 43, 73, 80, 94, 19, 23, 41, 21, 36, 71, 62, 52, 25, 87, 15, 52, 76, 42, 10]
data2 = [5, 81, 46, 17, 20, 7, 3, 51, 43, 3, 42, 18, 1, 9, 15, 21, 5, 31, 66, 3, 61, 19, 6, 17, 16, 28, 1, 17, 8, 34, 15, 5, 12, 45, 7, 25, 7, 5, 2, 8, 18, 26, 44, 8, 4, 10, 72, 20, 30, 40, 34, 6, 14, 30, 17, 49, 4, 2, 15, 4, 20, 23, 8, 10, 22, 1, 54, 1, 15, 19, 5, 14, 27, 35, 11, 18, 24, 3, 6, 8, 22, 27, 17, 0, 23, 7, 7, 5, 11, 64, 29, 17, 21, 9, 3, 33, 6, 3, 14, 13, 17, 34, 8, 36, 3, 53, 5, 29, 11, 31, 31, 3, 27, 53, 7, 15, 3, 11, 19, 5, 25, 2, 4, 23, 21, 12, 27, 37, 4, 41, 23, 28]

#Imprimir 10 entradas de data1 y data2
print(data1[:10])
print(data2[:10])
# Out:
# [71, 87, 21, 18, 32, 72, 75, 43, 56, 25]
# [5, 81, 46, 17, 20, 7, 3, 51, 43, 3]

# %% [markdown]
# ## Estandarizar los datos:
# 1. Calcular su Media $\mu = (\frac{\Sigma(x_i)}{n})$
# 2. Calculate su Desviación Estándar $(\frac{\Sigma(x_i^2)}{n} - \mu^2)^{1/2}$.
# 3. Para cada elemento realice lo siguiente:
#
#     $z_i = \frac{x_i - \mu}{\sigma}$

# %%
### edTest(test_std) ###
#Usar list comprehension para encontrar el cuadrado cada elemento de la lista data1
data_sq1 = [item**2 for item in data1]
#Calcule la media y la desviación estándar usando la fórmula provista en la celda marcada arriba
mean1 = sum(data1)/len(data1)
std1 = ((sum(data_sq1)/len(data1))-mean1**2)**(1/2)

#Estandarizar los datos usando list comprehension y mostrar 10 elementos
std_data = [((item2-mean1)/std1) for item2 in data1]
print(std_data[:10])
# Out:
# [0.5959400210344328, 1.1918800420688656, -1.2663725446981695, -1.3781112986421258, -0.8566637802369971, 0.6331862723490848, 0.7449250262930409, -0.4469550157758245, 0.03724625131465205, -1.1173875394395614]

# %% [markdown]
# ### De manera similar estandarizar data2

# %%
# %% [markdown]
# ## Escribir una función
# Copiar y pegar manualmente el código para procesar todos los diferentes conjuntos de datos sería muy tedioso y también reduce la legibilidad del código, lo que aumenta las posibilidades de pequeños errores.
#
# Es por eso que declararemos una función para que haga el trabajo por nosotros. Cada vez que queremos estandarizar datos, todo lo que tenemos que hacer es simplemente llamar a la función.

# %%
### edTest(test_func) ###
#Defina una función que calcule la media y la desviación estándar de los datos de entrada y devuelva datos estandarizados
def standardize(data):
  data_sq = [item**2 for item in data]
  mean = sum(data)/len(data)
  std = ((sum(data_sq)/len(data))-mean**2)**(1/2)
  return [((item2-mean)/std) for item2 in data]

# %%
#Llame a la función de estandarización en data1 y mostrar 10 elementos
data1_std = standardize(data1)
print(data1_std)
# Out:
# [0.5959400210344328, 1.1918800420688656, -1.2663725446981695, -1.3781112986421258, -0.8566637802369971, 0.6331862723490848, 0.7449250262930409, -0.4469550157758245, 0.03724625131465205, -1.1173875394395614, 1.3036187960128216, 0.4842012670904766, -0.8566637802369971, -1.4153575499567776, -1.3408650473274737, -0.9311562828663011, -0.6331862723490848, 1.0428950368102572, 1.4526038012714297, 0.0744925026293041, -1.1173875394395614, -1.1173875394395614, -0.1489850052586082, -0.0744925026293041, 1.3036187960128216, -0.7449250262930409, 0.5959400210344328, -0.0744925026293041, 1.4153575499567776, -1.1546337907542135, -0.782171277607693, -1.4526038012714297, -0.6331862723490848, 1.527096303900734, -1.1918800420688656, -0.3352162618318684, 0.782171277607693, -0.11173875394395613, 1.3781112986421258, 0.8566637802369971, -1.2291262933835174, -0.3352162618318684, 0.4842012670904766, 1.63883505784469, -1.0056487854956053, -0.37246251314652046, -0.0744925026293041, 0.4097087644611725, 1.0801412881249093, -1.564342555215386, -1.2291262933835174, -0.6704325236637368, -1.1546337907542135, 1.0428950368102572, 1.3781112986421258, 0.9684025341809532, -0.782171277607693, 1.3408650473274737, -1.3781112986421258, 0.782171277607693, -1.4153575499567776, 1.1918800420688656, 1.4526038012714297, 1.527096303900734, 0.03724625131465205, 0.5214475184051286, -1.0428950368102572, 1.4526038012714297, -0.9311562828663011, 1.2291262933835174, 1.1173875394395614, -0.782171277607693, 0.4469550157758245, 0.6331862723490848, 0.3352162618318684, 1.4898500525860818, 0.819417528922345, -0.4469550157758245, 0.4097087644611725, -0.893910031551649, -1.3036187960128216, 0.893910031551649, 0.819417528922345, -0.782171277607693, 1.1918800420688656, -0.4469550157758245, 1.1546337907542135, -0.7076787749783888, 0.7449250262930409, -1.0056487854956053, 1.6015888065300379, -1.6015888065300379, -1.676081309159342, -1.3036187960128216, -0.9311562828663011, -0.11173875394395613, 0.9684025341809532, 1.2663725446981695, 0.22347750788791226, 0.0, 0.6704325236637368, -0.3352162618318684, -0.819417528922345, 1.6015888065300379, 0.5586937697197807, -1.3036187960128216, -0.1489850052586082, 1.4153
# %% [markdown]
# ## Función de desestandarización
# A menudo, en la ciencia de datos, realizamos manipulaciones en el conjunto de datos estandarizados (porque generalmente es más fácil) y luego lo volvemos a convertir a la escala original desestandarizando.
# Entonces, escribamos una función para recuperar los datos mediante la desestandarización.

# %% [markdown]
# ## Función para desestandarizar
# Necesitará los valores `media` y `std` originales para desestandarizar. Realice lo siguiente en cada elemento:
#
# $x_i = z_i . \sigma + \mu$

# %%
### edTest(test_de) ###
# Escriba una función que tome datos, media y desviación estándardar como entrada
# y devuelve datos no estandarizados
# Asegúrate de usar la media y std correctos para
# data1 y data2 calculados antes
def destandardize(mean,std,data):
  return [(item*std)+mean for item in data]

# %%
### edTest(test_de1) ###
#Usa la media y std de data1 calculado antes y desestandarizar data_std1
data_de1 = destandardize(mean1, std1, std_data)
print([int(item) for item in data_de1])
# Out:
# [71, 87, 21, 18, 32, 72, 75, 43, 56, 25, 90, 68, 32, 17, 19, 30, 38, 83, 94, 57, 25, 25, 51, 53, 90, 35, 71, 53, 93, 24, 34, 16, 38, 96, 23, 46, 76, 52, 92, 78, 22, 46, 68, 99, 27, 45, 53, 66, 84, 13, 22, 37, 24, 83, 92, 81, 34, 91, 18, 76, 17, 87, 94, 96, 56, 69, 27, 94, 30, 88, 85, 34, 67, 72, 64, 95, 77, 43, 66, 31, 20, 79, 77, 34, 87, 43, 86, 36, 75, 27, 98, 12, 10, 20, 30, 52, 81, 89, 61, 55, 73, 46, 33, 98, 70, 20, 51, 93, 33, 52, 94, 46, 83, 43, 73, 80, 94, 19, 23, 41, 21, 36, 71, 62, 52, 25, 87, 15, 52, 76, 42, 10]

# %%
### edTest(test_de2) ###
#Usa la media y std de data2 calculado antes y desestandarizar data_std2

data_de2 = destandardize(mean2, std2, std_data2)
print([int(item) for item in data_de2])
# Out:
# [5, 81, 46, 17, 20, 7, 3, 51, 43, 3, 42, 18, 1, 9, 15, 21, 5, 31, 66, 3, 61, 19, 6, 17, 16, 28, 1, 17, 8, 34, 15, 5, 12, 45, 7, 25, 7, 5, 2, 8, 18, 26, 44, 8, 4, 10, 72, 20, 30, 40, 34, 6, 14, 30, 17, 49, 4, 2, 15, 4, 20, 23, 8, 10, 22, 1, 54, 1, 15, 19, 5, 14, 27, 35, 11, 18, 24, 3, 6, 8, 22, 27, 17, 0, 23, 7, 7, 5, 11, 64, 29, 17, 21, 9, 3, 33, 6, 3, 14, 13, 17, 34, 8, 36, 3, 53, 5, 29, 11, 31, 31, 3, 27, 53, 7, 15, 3, 11, 19, 5, 25, 2, 4, 23, 21, 12, 27, 37, 4, 41, 23, 28]
